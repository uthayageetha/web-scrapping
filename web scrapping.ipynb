# %% [markdown]
# # WEB SCRAPPING

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=laptops&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=laptops&requestId=27f45dab-5fc1-4f75-b414-b4e612130971&as-searchtext=l"

# %%
permit=requests.get(url)

# %%
permit
# Out:
# <Response [200]>

# %%
laptop=BeautifulSoup(permit.text)

# %%
laptop
# Out:
# <!DOCTYPE html>
# ...

# %%
import pandas as pds

# %%
laptop_brand=laptop.select("._4rR01T")

# %%
laptop_brand
# Out:
# [<div class="_4rR01T">Lenovo IdeaPad 3 Intel Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14ITL05 Thin and Light Lap...</div>,
#  <div class="_4rR01T">Lenovo Intel Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop</div>,
#  <div class="_4rR01T">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeForce G...</div>,
#  <div class="_4rR01T">ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ322WS Thin and Light La...</div>,
#  <div class="_4rR01T">ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5 Hexa Core AMD R5-4600H - (8 GB/512 GB SSD/Windows 11 Ho...</div>,
#  <div class="_4rR01T">ASUS VivoBook 14 (2021) Celeron Dual Core - (4 GB/256 GB SSD/Windows 11 Home) X415MA-BV011W Thin and L...</div>,
#  <div class="_4rR01T">RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop</div>,
# ...

# %%
laptop_price=laptop.select("._1_WHN1")

# %%
laptop_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹33,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,685</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹63,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹23,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹84,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹47,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹51,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹50,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹40,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹33,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹52,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,158</div>,
#  <div class="_30jeq3 _1_WHN1">₹27,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹53,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹40,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹74,500</div>,
#  <div class="_30jeq3 _1_WHN1">₹38,990</div>,
# ...

# %%
import pandas as pds

# %%
laptop_table=pds.DataFrame(laptop_price,columns=["laptop price"])

# %%
laptop_table
# Out:
#    laptop price
# 0       ₹33,990
# 1       ₹25,685
# 2       ₹51,990
# 3       ₹38,990
# 4       ₹63,990
# 5       ₹23,990
# 6       ₹39,990
# 7       ₹84,990
# 8       ₹47,990
# 9       ₹51,990
# 10      ₹36,990
# 11      ₹50,990
# 12      ₹40,990
# 13      ₹33,490
# 14      ₹52,990
# 15      ₹36,158
# 16      ₹27,990
# 17      ₹53,990
# 18      ₹40,990
# 19      ₹74,500
# 20      ₹38,990
# 21      ₹40,990
# 22      ₹37,490
# 23      ₹47,990

# %%
laptop_table=pds.DataFrame(laptop_brand,columns=["laptop_brand"])

# %%
laptop_table
# Out:
#                                          laptop_brand
# 0   Lenovo IdeaPad 3 Intel Core i3 11th Gen - (8 G...
# 1   Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 3   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...
# 4   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...
# 5   ASUS VivoBook 14 (2021) Celeron Dual Core - (4...
# 6   RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...
# 7   APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...
# 8   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...
# 9   ASUS VivoBook K15 OLED (2022) Ryzen 5 Hexa Cor...
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...
# 11  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...
# 12  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...
# 13  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...
# 14  HP Pavilion Ryzen 5 Hexa Core 5625U - (8 GB/51...
# 15  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen -...
# ...

# %%
laptop_table["laptop_price"]=laptop_price

# %%
laptop_table
# Out:
#                                          laptop_brand laptop_price
# 0   Lenovo IdeaPad 3 Intel Core i3 11th Gen - (8 G...    [₹33,990]
# 1   Lenovo Intel Celeron Dual Core - (8 GB/256 GB ...    [₹25,685]
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    [₹51,990]
# 3   ASUS Vivobook 15 Core i3 11th Gen - (8 GB/512 ...    [₹38,990]
# 4   ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...    [₹63,990]
# 5   ASUS VivoBook 14 (2021) Celeron Dual Core - (4...    [₹23,990]
# 6   RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB ...    [₹39,990]
# 7   APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/M...    [₹84,990]
# 8   ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 ...    [₹47,990]
# 9   ASUS VivoBook K15 OLED (2022) Ryzen 5 Hexa Cor...    [₹51,990]
# 10  HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...    [₹36,990]
# 11  HP Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD...    [₹50,990]
# 12  DELL Vostro Core i3 11th Gen - (8 GB/1 TB HDD/...    [₹40,990]
# ...
